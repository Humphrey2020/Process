# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.DataFrame({'MONTH':['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEPT','OCT','NOV','DEC'],
                  'NUMBER OF STUDENT':[10,15,60,40,50,30,50,4000,5000,10000,4500,2000],
               'SAT_SCORE':[1230,1450,1400,1340,1250,1300,1380,1350,1280,790,1370,1230] })
df.plot.bar('MONTH')
df.title('PERFORMANCE OF STUDENT WHO SAT FOR 2019 SAT')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-96c41f4e1f0a> in <module>
#       6                'SAT_SCORE':[1230,1450,1400,1340,1250,1300,1380,1350,1280,790,1370,1230] })
#       7 df.plot.bar('MONTH')
# ----> 8 df.title('PERFORMANCE OF STUDENT WHO SAT FOR 2019 SAT')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'title'
